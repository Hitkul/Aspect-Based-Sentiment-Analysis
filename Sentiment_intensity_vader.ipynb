# %%
#using VADER to calculate sentiment analysis
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from string import punctuation
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
#loading data
headlines = pd.read_csv('FiQA_train_ABSA_financial_headlines.tsv',delimiter='\t',header=0)
posts = pd.read_csv('FiQA_train_ABSA_financial_posts.tsv',delimiter='\t',header=0)
posts = posts.drop(['Unnamed: 0', 'id'],axis=1)
headlines = headlines.drop(['Unnamed: 0', 'id'],axis=1)
posts_text = posts.iloc[:,:1]
posts_score = posts.iloc[:,1:]
headlines_text = headlines.iloc[:,:1]
headlines_score = headlines.iloc[:,1:]
text_frames = [posts_text,headlines_text]
score_frames = [posts_score,headlines_score]
text = pd.concat(text_frames)
score = pd.concat(score_frames)

# %%
sentences = []
intensity = []
for sent in text.values.tolist():
    sentences.append(sent[0])
for scr in score.values.tolist():
    intensity.append(scr[0])

# %%
# turn a sentence into clean tokens
def clean_sentence(sentence):
    #remove multiple repeat non num-aplha char !!!!!!!!!-->!
    sentence = re.sub(r'(\W)\1{2,}', r'\1', sentence) 
    #removes alpha char repeating more than twice aaaa->aa
    sentence = re.sub(r'(\w)\1{2,}', r'\1\1', sentence)
    #removes links
    sentence = re.sub(r'(?P<url>https?://[^\s]+)', r'', sentence)
    # remove @usernames
    sentence = re.sub(r"(?:\@|https?\://)\S+", "", sentence)
    #removing stock names to see if it helps
    sentence = re.sub(r"(?:\$|https?\://)\S+", "", sentence)
    #remove # from #tags
    sentence = sentence.replace('#','')
    # split into tokens by white space
    tokens = sentence.split()
    # remove punctuation from each token
    table = str.maketrans('', '', punctuation)
    tokens = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
#     tokens = [word for word in tokens if word.isalpha()]
#no removing non alpha words to keep stock names($ZSL)
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) > 1]
    tokens = ' '.join(tokens)
    return tokens

# %%
for i in range(len(sentences)):
    sentences[i] = clean_sentence(sentences[i])
sentences
# Out:
# ['looking weak could good short setup',
#  'Looking test 925 resistance point cc cfrazierjr traders',
#  'prerelease shtty earnings something',
#  'ContrarianAlert Why Zynga Failed',
#  'shorts getting nervous',
#  'times start wonder enough shares beast keeps moving',
#  'points two Facebook games accuses copyright infringement',
#  'Following mornings EPS blew added longs',
#  'No worries always said thered sucker rallies trend congrats',
#  'One thing cant short food Its barely getting warm chicago looks like drought conditions soil already',
#  'getting readyTarget plus close better avg daily Volume',
#  'OPPY reduces price target Yum Brands YUM factoring troubles company seeing China',
#  'Chinese ADRs heading higher watchlist',
#  'high volume blast Friday goes higher',
#  'price stocks times lower annual earnings could resist buying everyone selling',
#  'Hit With Lawsuit Russian Search Engine',
#  'Long setup Closed 20MA MACD cross November catalyst',
#  'In response thoughts Nikesh dont think right fit visionary aspects',
#  'RT Chartology Yahoo Crazy looking chart nearing breakout resistance line',
#  'These companies shld worried iCloud',
#  'breakout would constitute technical entry short term trader',
#  'Long sum moe',
#  'wayy overvalued right IMO Should trading single digits May take short pos earnings Near term target 18',
#  'RT Im gonna keep Grated muppets going ruck higher Im',
#  'looking good',
#  'This goes green many shorts toast',
#  'gold going parabolic wonder keep chasing tops boys',
#  'arent loading Future profits huge Surely arent investing stock based Q1',
#  'Not surprising would pull something like considering small businesses called scam years',
#  'PAIN',
#  'Double bottom 52',
#  'Found good bull setups week Lets see mkt helps',
#  'sold xoma buy back April',
#  'Buy stop 80 retakes 200 day MA',
#  'sectorbreadth Utilities enjoyed best action sectors improved bullish breadth',
#  'seriously nothing says strong growth like well played',
#  'long April calls',
#  'seriously nothing says strong growth like well played',
#  'Bounced target buy area bought hedge watch 50mas slope',
#  'RT VMarkets Are Still Acting Weak',
#  'looking good Just need 910 stay support Note broke area lighter volume Not good sign',
#  'Watch bancostheyre holding relatively well compared broad market large buying backburner',
#  'energy still failing close 10D MA continues stand weak',
#  'weakest sector year possible false breakout',
#  'No It’s Not Time To Buy Energy Stocks Yet',
#  'cap ex info positive remain bullish looking entry long term view',
#  'RT Down day biotechs Good load Be confident Agreed downness',
#  'Long 2462',
#  'Well goat least know sector white hot next weekhuge buy names work',
#  'Casinos red bell 075 047 047 unusual comibinations whats running whats red bell',
#  'big bounce',
#  'THE play today aint bad iether',
#  'Im going tomorrow evening limit order',
#  'Decent pull back',
#  'No It’s Not Time To Buy Energy Stocks Yet',
#  'slid fouryear low OPEC kept oil production unchanged',
#  'Downbeaten stocks may ripe buys',
#  'stopped even yesterdays entry 1201 probably headed 1130s',
#  'Double bottom handle buy point 5649',
#  'Held recent double bottom buy point 5657 almost penny today',
#  'BULLISH MACD CROSSOVER RSI STO going 734 MA50 res could run',
#  'Google Will Soon Start Selling Chromebooks At Walmart And Staples Other Retailers Coming Soon',
#  'New recommendation Carl Kirst BMO Capital Markets BUYPrice target',
#  '11 industrialgoods stocks insiders bullish',
#  'lots nice setups Energy liking Whiting day',
#  'closed 2855 producing Bullish MACD Xover clear 3158 could see 3614 use 2826 Stop',
#  'BoD right reject offer That company low economy type mismanagement anything',
#  'closng higher',
#  'Bought little yesterday hoping earnings pop',
#  'MoneyLosing OverValued China IPO Junk BUY instead',
#  'trade continuing nicely yesterday almost yesterday entry deal pricing tonight looking strong',
#  'Walter Investment Management Corp Receives Sell Compass Point',
#  'ESPN Files Lawsuit Against Verizon',
#  'StockMasters European Debt Keeps Stocks Down',
#  'adding position',
#  'move bring close see',
#  'pair trade one favorite trade consistent gains small',
#  'buying last round shorts next week bring average bought ladders tripplying',
#  'parties loaded volatility back',
#  'watching closely Until breaches daily weekly 5ma touching Still room downside absent black swan',
#  'Trying hold drop seems inevitable point longer takes bounces along harder fall',
#  'Another great day millions gains Tuesday shorts get caught tall grass',
#  'VIVUS bear raid effect Stock 12',
#  'like optimism moving NCE Agenda may simple claim active moiety',
#  'Long shares call option expiration umm TODAY Hitting HOD',
#  'Vertex Monthly lower hilower lo Long term uptrend intract far',
#  'THIS STOCK HAS VERY VERY VERY VERY VERY HIGH PROBABILITY OF RALLYING TOMORROW ANDOR EARLY NEXT WEEK',
#  'telling guysthis stock bc European approval newsafter news nothing left Dont keep anymor',
#  'Loving volume Above average higher yesterday already',
#  'These companies shld worried iCloud',
#  'soars premarket business split announcement rumors looking shed stake buyer LOL',
#  'Got nice push today following small sweepers May morning',
#  'China winners',
#  'Sees Q2 2014 total net revenues mln mln yoy growth rate approximately 1220 1249',
#  'similar pattern like beginning May Did sell Same nowwill go much higher drop',
#  'delivering goods lets see spill chinese internet names started wake last week',
#  'hot',
#  'Over 16 conviction Im buyer good ride 20',
#  'PAIN',
#  '54 Highest close since Nov 14th day gap',
#  'March LED light bulb prices rise Japan fall markets',
#  'Downbeaten stocks may ripe buys',
#  'Buffetts 13F Shows New Stakes CVS Visa General Dynamics',
#  '17 10 IBD50 list Both look good',
#  'Current holdings via options Long Short',
#  'think puppy going steam roll holidays It monster',
#  'potential bearish shark pattern point taken',
#  'buying last round shorts next week bring average bought ladders tripplying',
#  'broke 1000 amazing Not really 1st time wont last',
#  'trouble getting yest TD Amer wanted 19 got AH 1868 better held overnight',
#  'would take profits',
#  'Put chum key support next level careful',
#  'Take shot 1040',
#  'RT still rising RSI MACD bond buying signaling bad moves market',
#  'major resistance right Can go much higher break May take several attempts days week',
#  'EURUSD Finding Support Near 110 Level',
#  'making new highs year Doesnt normally produce great stocks trade may bad swing',
#  'Long setup Reported good earnings',
#  'Crude Oil Bears Take Clear Near Term Advantage',
#  'No It’s Not Time To Buy Energy Stocks Yet',
#  'slid fouryear low OPEC kept oil production unchanged',
#  'Brent back 49 whats WTI 45 hahaha yes go 44s soon',
#  'HeadShoulders bullish reversal setup breakout Oil Gas Pipleline stock',
#  '100 upside left next mnths based nov 2010 100 based july 2007 History rhymes',
#  'RT Wanna see awesomely bullish stocks Check Europe might mess people still shipping stuff',
#  'like Ascending Triangle 30minute chart Breakout coming Monday promising',
#  'another story stock unhappy ending Typical Yeah Pretty much We seen many',
#  'Bot puts',
#  '543 megaphone watch',
#  'new large player sells stocks',
#  'Will cold put dent massive horizontal rig production Who knows',
#  'gonna start shorting every 10 move',
#  'sold half Long entry yesterday noted Moved stop entry price',
#  'EURUSD Finding Support Near 110 Level',
#  'still trouble resistance line Should resolve soon',
#  'congress probably long fcking right',
#  'Murray leaves competitor Adidas Diversifies Adds International exposure And tennis Murray 2012 US Open Olympic Gold',
#  'close 2864 ready rock roll',
#  'Sold 45 hedging 45 Letting calls ride solo',
#  'Buying calls puts tomorrow',
#  'still',
#  'chartist news MM talk orchestrated BS Long tech early Jan straight calls',
#  'rocket ship',
#  'buying last round shorts next week bring average bought ladders tripplying',
#  'daily chart upcoming first support days weeks',
#  'Short week next week Charts targeting high Still holding 150 shares 450 SL 7911',
#  'break new highs lots technicals looking great right',
#  'reports Q1 EPS versus estimated beating EPS Up 19 quarter last year',
#  'Q3 adjEPS 60c beats 2c sales sees Q4 EPS 2836c vs cons 54c sales vs cons',
#  'CHUNK OF DEC PUTS BOUGHT AT 40Â¢ OPENING',
#  'MoneyLosing OverValued China IPO Junk BUY instead',
#  'may take days wks months watch happened IPO mrkt needs washout hunt well need wait stalk',
#  'The best scenario going forward stock slowly falling everydayWhich quite probable',
#  'So todays close 81514 Im long longerterm technical swing long basis',
#  'one good announcement shorts start quietly covering people buy quick large gain Dont listen neg bs',
#  'likes posted ystdy think reports solid quarter guides higher putting options accordingly',
#  'sad thing move takeover rumor sold next day',
#  'TTWO Long Idea TTWO strong weak tape',
#  'End Of Day Scan Bullish MA Crossovers wwdailystockplayscom',
#  'long 800',
#  'watch 345',
#  'Tesla Model sales exceed target profitability guidance amended upward',
#  'see downside next two weeks careful 20 dollars drop potential vs 10 moved',
#  'Not sure guy Northland Capital CNBC recommends Tesla straight face PT joke bubble buyerbeware',
#  'gyrating S1 gap keeping eye S2',
#  'think leader frisky colt got thrown Do get back horse doesnt gap open',
#  'finally broke free big brothers shadow',
#  'Tesla 600 Yearly Return Is Not An Ordinary Occurrence',
#  'nice wedge could go either way maybe tomorrow know',
#  'looking goodid love see basing action letting RSI take breather',
#  'So todays close 81514 Im long longerterm technical swing long basis',
#  'You love types articles SS interest rose 1215 day hit lows',
#  '215 forget chart invest elon fund acjieve misson faster would contribute without doubr',
#  'Elon Musk’s Comparision Of With Doesn’t Go Well',
#  'stopped 23153 386 loss',
#  'Long setup MACD cross',
#  'Ascending triangle gives bullish bias chart Breakout 84 positive',
#  'While think winner ringing register We entered 92 dollars 147 hell win Tony strikes',
#  'Looks like explosive setup break 20EMA 105 level',
#  'Buying calls puts tomorrow',
#  'daily chart upcoming first support days weeks',
#  'Short week next week Charts targeting high Still holding 150 shares 450 SL 7911',
#  'In 7324',
#  'Still top dog Intermarket RS',
#  'recent dips created buying opportunities Using MA Triangular 34 reference Latest BUY Fri',
#  'Ten year yield weekly 10 year yield still bearish hence 710 year bond fund bullish',
#  'Oh man hospital reits slaughtered Even plus div yield',
#  'reporting today reward better good earnings sold 50 last two days yet rallied',
#  'anyone long flush please accept condolences Congrats short wasnt either way',
#  'minor double top 50ma would watch see quickly reclaim mas',
#  'Found good bull setups week Lets see mkt helps',
#  'Is Tiffanys overvalued See FAST Graphs',
#  'Three hot stocks today Thanks',
#  'Never told situation Buy dip',
#  'last article June 2012 buying back chunk prices Nicely done',
#  'While fear mechanically driving public markets LOWER record corp cash cheap financing fueling wave acquisitions',
#  'Still holding next year',
#  'RT bailed looking good thought looks boring much overthink',
#  'Sounds like cost cutting run course Tom Long needs find way turn around Miller Lite quickly',
#  'Found good bull setups week Lets see mkt helps',
#  'like breakout long well getting 100 200 MA could see run',
#  'ATT Issues Statement On Debt Ceiling Potential US Government Default',
#  'board',
#  'regular scrappy usually presents Sales weak margins debt still way',
#  'Im liking price action currently target 2400 year end',
#  'RT In mostly red tape morning biggest St50 gainers',
#  'reporting today reward better good earnings sold 50 last two days yet rallied',
#  'Toxic Stocks Raising Red Flags Sell This Week',
#  'Chanos If pick one would',
#  'Quality Stocks With High Cash Returns',
#  'exited calls wayway early',
#  'Well goat least know sector white hot next weekhuge buy names work',
#  'Long 2750 wTrailing Stop 2777 prior Stops Weekly Chart',
#  'didnt trade last week big red candle Friday failed Could see support around',
#  'retested lows Should rise steadily It hit 21 trading days ago Sept 18 Itll',
#  'splat poor Q1 orders',
#  'Lots metal stocks look like 510 run awaits Long high quality names go metal prices cooperate',
#  'added 6433 6413 low',
#  'Another keep eye Wiseguys inhaled Apr calls Friday payin 2530¢ 68x usual VOL',
#  'StockMasters European Debt Keeps Stocks Down',
#  'Crude Oil Bears Take Clear Near Term Advantage',
#  'bull move ended waiting next setup',
#  'Dont hang bull hat yet Next week pop higher QE3 hope back feds day meeting',
#  'Yes buy everything World fine',
#  '11235 gotta hold',
#  'FMMF Big Drop Hedge Fund Exposure Market Q3 Can blame Even sharks dont trust market',
#  'Nice little cupandhandle shaping 15minute Endofday favours good day index Will see gap open',
#  'RT VMarkets Are Still Acting Weak',
#  'RT correleation dollar index simply amazing finds support retreats like clockwork',
#  'add short 1192',
#  'Were holding Wednesday Thursday closes Im leaning bullish Small postions Waiting',
#  '27 EU members futher declines',
#  'thinking last entry good needs push',
#  'RT still rising RSI MACD bond buying signaling bad moves market',
#  'RT think shorting close might play high beta reversinglooks worth shot',
#  'starting creep sits near hod',
#  'weak close',
#  'rather neutral bullish rather bearish Still stock pickers market',
#  'RT 80 Greek bondholders short US market get money back If managed lose',
#  'pair trade one favorite trade consistent gains small',
#  'Long 12 position 13789',
#  'years alot worry',
#  '14221 difficult point cross',
#  'Short interest increases yet via',
#  'Last year mkt fell debt downgrade early Aug SP500 corrected 10 DG due slow growth',
#  'trade continuing nicely yesterday almost yesterday entry deal pricing tonight looking strong',
#  'Market seems stuck mud',
#  'IMO Fed stimulus kind cud defended Obama thus exceptionally bullish Romney mkt economy FED',
#  'parties loaded volatility back',
#  'buy programs popping close print cheap money means higher stock prices robot buying',
#  'All time high tomorrow 150k shares Dec 13 2007',
#  'wouldnt surprised see green close',
#  'true short market using plenty reverse ETFs alternative rather bubble creation',
#  'Could pride social media gettin ready fall chart rolling',
#  'Tomorrow party time Bears 55',
#  'cmon bulls buy DIPS',
#  'nice chart shows distinctive channel dip see bottom',
#  'still wants higher think',
#  'Monday commodity weakness staple 2013 right along consumersmallcap multiple expansion algo',
#  'bumping head declining daily 8ma overhead resistance Then big brother 50ma',
#  'Less 02 people calling bearish Some heading exits already Maybe crash Disturbing',
#  'hows oil soundgood economy',
#  'gold going parabolic wonder keep chasing tops boys',
#  'US Adds 321K Jobs In November Most Since 2012 Unemployment Rate Remains At 58 Gold Futures',
#  'feel people buying ones finger sell button',
#  'bubble stock buy backs sure fed anything deflation may coming Hard macro mkt',
#  'In 195 calls 78',
#  'eod run',
#  'Alibaba IPO hoopla can’t hide risk Chinese stocks notForMe',
#  'Relief rally becomes belief rally',
#  'Basing nice close 2418 bullish watch close near HOD Currently',
#  'The Baltic Dry Index lower days 30 years',
#  'Greece FOMC much week Moves sides possible larger ranges though Stay nimble cautious',
#  'spy trending stocktwits good sign usually means downtrend ive actually noticed many stocks trend hmm',
#  'Homebuilders breaking support watch one',
#  'Looks weak bottom yet May around 188 levels see Stay Short SPY till',
#  'Another great day millions gains Tuesday shorts get caught tall grass',
#  'Looks like bear traps getting laid faster Cadbury Creme Eggs Easter Bunny',
#  'extreme win today cents 2009 low 10year percent life bowl cherries great short setting',
#  'train cellar bottom looks like confirmation hold 13650',
#  'fast 56pc dive',
#  'market lot faith ECB',
#  'Still cogniscicent Euro mess ensuing newsflow',
#  'Ha ha 25 banks fail stress test',
#  'Time stomp dreams',
#  'Nice little cupandhandle shaping 15minute Endofday favours good day index Will see gap open',
#  'rather neutral bullish rather bearish Still stock pickers market',
#  'going',
#  'RS Sweet want break new 52week The earnings growth justifies way higher',
#  'Bet farm hopeful good things soon',
#  'year chart suggests possible next months',
#  'It fineIMHOI NO worries real deal hereHOLDING',
#  'Google Will Soon Start Selling Chromebooks At Walmart And Staples Other Retailers Coming Soon',
#  'Equity indexes working positive engulfing March Smallcaps semis fakeout bout',
#  'Amazing run since middle March obvious qualitytastiness burgers factored price advance',
#  '4271 Float Short LoL',
#  'printed daily buy candle Use close below1725 daily stop initial target 1850 1955',
#  'Nomura ests Xbox platform lose least 2014 may profitable another year',
#  'Found good bull setups week Lets see mkt helps',
#  'Equity indexes working positive engulfing March Smallcaps semis fakeout bout',
#  'RT VMarkets Are Still Acting Weak',
#  'Equity indexes working positive engulfing March Smallcaps semis fakeout bout',
#  'got sell signal 64 needs take 3928 go higher otherwise headed lower 3760 gap 3538',
#  'today aside setting another drop 33 36 targetOvervalued sector ETF',
#  'yeah Even looking pretty attractive versus pig Or SOX trading 36x reported earning',
#  'weekly calls 2895 23 25 321 volume Worth chance jmho',
#  'still needs fill 2797 decent supt hereexpect upside 30',
#  'If shorted GoldSilver recently bottom enjoy bull run started',
#  '444 18 AWFUL 4250',
#  'POS saying years Going lower Forget go short',
#  'bull bear way cut',
#  'US Adds 321K Jobs In November Most Since 2012 Unemployment Rate Remains At 58 Gold Futures',
#  'turning Coming far could go far Stock price implies pay nothing business',
#  'Surprising see sales numbers still holding well guess high end might concern',
#  'Long setup Watch continuation volume expansion Hot sector',
#  'Bounced target buy area bought hedge watch 50mas slope',
#  'Add positions posted earlier Exit',
#  'LONG',
#  'even though report untrue proven unture damage done No one wants touch',
#  'Watch aftpre mrkt Could technical sellersalso shorts getting back gamewell see',
#  'hear short crap every time jumps back range 70 bucks',
#  'RT going end red highly doubt',
#  '100 upside left next mnths based nov 2010 100 based july 2007 History rhymes',
#  'big holding Ali Baba news making big move premarket near test',
#  'Basing nice close 2418 bullish watch close near HOD Currently',
#  'Bid Reargument Denied Judge',
#  'Red Daily Triangle Up Long Position',
#  'When squeezes nakeds might lose everything Ive played game head handed Go elsewhere',
#  'Synergy Pharma Soars 67 Today On Positive Phase Results',
#  'looking weak possibly ready let go',
#  '18112013 BUY Mentalstop around Target wwswingstocktraderscom',
#  'China winners',
#  'Three hot stocks today Thanks',
#  'Quality Stocks With High Cash Returns',
#  'These companies shld worried iCloud',
#  'That bearish outside day Tuesday significant 200 day resistance still intact opinion',
#  '146 1532 picking speed May 16 calls 35 19 Next week calls 11c',
#  'covered last 362',
#  'whats great move still hold since back day yesterday Marry Christmas',
#  'finally broke free big brothers shadow',
#  'gain drop percentage point drop dime Earnings going explosive ever direction goes',
#  'Goldman Suks cant bring one day today Look strong solar rebound today',
#  'somewhat tempting long side Inverse cuppa joes',
#  'getting sold',
#  'End Of Day Scan Bullish MA Crossovers wwdailystockplayscom',
#  'breaking downtrend line increasing volume move 2057 could see upside',
#  'Downbeaten stocks may ripe buys',
#  'Sprint CFO Sees Profitability From Lightsquared Upon GPS Clearance Network Vision Cash Flow Positive From 2014',
#  'Homebuilders breaking support watch one',
#  'guess havent seen month picture results This companys tech works better load',
#  'still holding 226 ydayno biggie',
#  'Tang really toxic keep bringing share price At least could let climb little dragging',
#  'This stock needs quadruple shot caffeine quickly might go grid bad news …sure havent seen good news yet',
#  'Equity indexes working positive engulfing March Smallcaps semis fakeout bout',
#  'That seems dangerous imo almost seems like chasing In general everyone bullish Ill',
#  'Dont catch falling knives think entry coming soon',
#  'bought 3500 shares today',
#  'Options expiration today Shares fly higher Monday money calls rolled buy shares',
#  'looking first profitable quarter years LONG STRONG',
#  '11 industrialgoods stocks insiders bullish',
#  'Nov 90 calls 208 Go Long exp imo Unless europeans keeps Fing around',
#  'Ross Stores Upgraded Outperform RBC Capital Markets',
#  'staying open good sign',
#  'day traders flushed start going slowly',
#  'More bleeding Monday',
#  'Wonder investors buying stock Its great company isnt Needs buyerslol',
#  'even canadian comeback',
#  'heck buying qwerky touch',
#  'going',
#  'buy stop 1482 full stop 1465',
#  'Plan rest week Holding stops accumulating pullback',
#  'BlackBerry owners cant hold stock Impossible',
#  'Another gain following last weeks huge call buying Apr calls',
#  'whos ever pushing crazy get ready suspended dividend turning growth stock blow earnings major buyback lol',
#  'seeking alpha research guy said step away ONshore oil svcs Atwood safe ha ha tempting',
#  'topping tail min chart 731 short',
#  'Chinese ADRs heading higher watchlist',
#  'bottoming Good time buy',
#  'Found good bull setups week Lets see mkt helps',
#  'Rowan Expands Share Repurchase Program million',
#  'upside today This thing severe low float If catalyst guy It run',
#  'March LED light bulb prices rise Japan fall markets',
#  'PAIN',
#  'Setting higher prices',
#  'All charts flashing oversold',
#  'would consider opportunity add position company right track still improving sales',
#  'Rival companies WATCO eyeing takeover interest',
#  'China winners',
#  'RT VMarkets Are Still Acting Weak',
#  'trying lead higher gonna tough',
#  'RT RT Breadth Consolidates After weeks steady gainsadvances mkt breadth slowe',
#  'Apple breaks major support levels watch',
#  'Basing nice close 2418 bullish watch close near HOD Currently',
#  'follow SELL signal internals 0623 technical SELL 0625 DOWN',
#  '51',
#  'Top Japan ETFs To Surge Higher In 2H',
#  'Looks like good entry',
#  'totally missed one jump 60 break test didnt congrats shorts',
#  'China winners',
#  'bad start week Trades 750 140 250 VVUS 110 160 80',
#  'Just added 300 shares',
#  'reviewing NFLX GMCRs massive recent recovery toward new highs give real shareholders encouragement questcor',
#  '2nd raise year Questcor Increases Quarterly Cash Dividend 20 Percent',
#  'little pullback fine erases todays gains cannot believe manipulation capable',
#  'Nasdaq Sets Up Breakout Part II via',
#  'Cook supply chain expert Do think would allow shortage deter Longs Correction mode',
#  'RT Long 395great find hope wold another still holding second 12',
#  'Oil gas name poised come base one many fastgrowing EP firms',
#  'Increasing Optimism Strength Calvin Klein Tommy Hilfiger Brands Read brief',
#  'congrats whoever bought sold im sorry',
#  '250 soon',
#  'My comes back three earning yesterday shorted short float long Very nice profit',
#  'Synthetic Long Discount Alert PROSPECT CAPITAL trading 1218 discount 20Jan',
#  'someone may pointed earlier think recall post man one careful',
#  'todays top gainers stocks',
#  'hanging tough market due analyst upgrades last week Up almost',
#  'Leader showing signs fatigue 1222 reversal hitting time high ugly Short candidate',
#  'bottom right',
#  'Descending triangle liking upside break',
#  'Quality Stocks With High Cash Returns',
#  'Three black crows followed potential bear flag looking promising short term IMO',
#  'Buy stop 5725 retakes 200 day',
#  'PNC Goldman Sachs Receive Dividend Hike Green Light But Dont Act',
#  'funny thing 19 AH approval',
#  'Ive asked Ill ask Why would anyone short stock midst short squeeze So dumb',
#  'Nice see turn corner You better Plugging believe',
#  'dont intend nay sayer cuz love stockCo may see 429',
#  'But Balance sheet value penney stock',
#  'bear raid',
#  'stomach high risk left thats extremely sensitive nasdaq',
#  'Closed short position Small gain Not interested options expiring worthless',
#  'Reiterating newbies notice doomsaying bears disappear climbs Theyre opportunists Ignore make',
#  'Been work evening Very intrigued technology growth potential',
#  'suggest read report Future bright',
#  'Yelp China onboard Looking good Paris conference December',
#  'Strong close coming',
#  'RT In mostly red tape morning biggest St50 gainers',
#  'Momentum building breakout trigger Long setup',
#  '11 industrialgoods stocks insiders bullish',
#  'Ackman making big added efficiency argument betting operational imporvement huge conglomerate go either way imo',
#  'End Of Day Scan Bullish MA Crossovers wwdailystockplayscom',
#  'The momo leaders taken one one Look best performer last year',
#  'back trendline 104',
#  'runs 50sma acquisition news',
#  'holding well today',
#  'Long',
#  'real assets NOT energy trading company',
#  '2nd time test 212030 bo zone Still breaking Moved stop 2080',
#  'close around good sign Tom continue upwards',
#  'Found good bull setups week Lets see mkt helps',
#  'need anoth time high new high',
#  'Lots metal stocks look like 510 run awaits Long high quality names go metal prices cooperate',
#  'might selling ahead earnings',
#  'bull flag daily earnings table tomorrow 12 moveWill straddle one earningslots vol guaranteed',
#  'gold going parabolic wonder keep chasing tops boys',
#  'Needs Follow Through Day break descending wedge',
#  'With Oil Prices Down Oil Stocks Looking Less Cheap',
#  'bought CALL OMNIVISION TECH EXP 122113 today earnings Should beat earnings',
#  '33 since 625 buy signal resistance 533 expect pullback 2nd half day break abov 533 continue rally 45 days',
#  'RT shares afterhours Q2 EPS 54c misses 3c sales vs cons adds buyback program',
#  'My comes back three earning yesterday shorted short float long Very nice profit',
#  'Never told situation Buy dip',
#  'The volume ratio 27 management ownership holds 57 total outstanding stock Major skin gamepositive',
#  'Like one lot',
#  'RT shorts breakin flag holding',
#  'RT Down day biotechs Good load Be confident Agreed downness',
#  'Continues base debate lingers ONT10 data next potential catalyst If positive stock quickly moves Downside limited',
#  'So sad see loved company eating dirt',
#  'Never told situation Buy dip',
#  'regional bank clearing new 52week high good base Relatively thin',
#  'slid fouryear low OPEC kept oil production unchanged',
#  'With Oil Prices Down Oil Stocks Looking Less Cheap',
#  'No It’s Not Time To Buy Energy Stocks Yet',
#  'Just stumbled upon amazing chart holy guac SUPER overbought',
#  'RT WTF Not complaining Got playing emotionsAMEN decent Co get bought IMHO',
#  'Add',
#  'stuff Will looking add shares get new high breakout',
#  'With Oil Prices Down Oil Stocks Looking Less Cheap',
#  'going',
#  'todays top gainers stocks',
#  'Going read quarterlies listen calls bead one looking beat interesting already',
#  '225 could get going',
#  'watch momentum',
#  'sideways',
#  'Patience pays holding theseif bought lowest nothing worry abouteven catching falling knife',
#  'longer term bullish',
#  'Gold 1400wow',
#  'US Adds 321K Jobs In November Most Since 2012 Unemployment Rate Remains At 58 Gold Futures',
#  'Buying Weakness 06302015',
#  'Well goat least know sector white hot next weekhuge buy names work',
#  'held well big gains Maybe finally move thisits still undervalued major upside',
#  'End Of Day Scan Bullish MA Crossovers wwdailystockplayscom',
#  'Found good bull setups week Lets see mkt helps',
#  '3star analyst Joe Wittine Longbow Research reiterated HOLD rating',
#  'Bull Of The Day Insperity Inc',
#  'RT Next long Im eyeing going one 400 shares though',
#  'ascending base breakout starting gain traction strong stock',
#  'Could strategy exit shorts big pop',
#  'This stock consolidating accumulation Day traders pegging range Will funny see shorts get creamed',
#  'glorious stuffthe selling days appear exhausted back BTFD old school stuffafter 720 10 etc',
#  'got hit hard lower AM looks like found support 1889',
#  'China Mobile China Telecom lead Q1 upside surprise IMO',
#  'Nice pop today Told ya would green haha Funny bring Im actually working story moment',
#  'Smartphone Wars Wound Samsung Nokia Rallies Chart Day',
#  '11 industrialgoods stocks insiders bullish',
#  'im saavy drops Im push investment another time',
#  'gapping time highs tradeideas',
#  'insiders got one wrong Looking bottom Rsi 30',
#  'End Of Day Scan Bullish MA Crossovers wwdailystockplayscom',
#  'If shorted GoldSilver recently bottom enjoy bull run started',
#  'RT close looking good bulls Will hold positions see close Keep buying',
#  'These companies shld worried iCloud',
#  'VISION short term consolidation movement higher',
#  'lows',
#  'support 21293 support 20945',
#  'Key price watch previous double top reject 21823',
#  'small pos short 180 wkly puts',
#  'Easy pop 500 end feb Then steady goes 600 second earnings report800 year end matter',
#  'lot high flyers like position getting wings clipped today would blame 6month comment Yellen',
#  'Love blood like vampireKeep bleeding',
#  'gets 440 theres good short spot',
#  'Netflix launching Japan fall Think one fastest launches country date',
#  'Lol earning report fear profit taken',
#  'buddy bet bank NFLX made',
#  'gets 26 patents goes gets patent goes 20 today',
#  'oversold',
#  'Lots metal stocks look like 510 run awaits Long high quality names go metal prices cooperate',
#  'Okay im looking add gold miner possibly lower pe tech name close tmrw Watching',
#  'follow SELL signal internals 0623 technical SELL 0625 DOWN',
#  'One Favorite Longs Right Now via',
#  'With Oil Prices Down Oil Stocks Looking Less Cheap',
#  'Is It Finally Right Time Invest National Bank Greece via',
#  'keep eye PM 080 low NBG spikes lows revisits 080 lower gowill next days wknd',
#  'Official EU announced default pmt due today addedwe discussionswhatever means',
#  'vwap 163 held trend line Should LOT radars',
#  'Oh snap Just went long LT',
#  'Covered small short 799 16 loss Flat day All cash',
#  'meanwhile absolute garbage still stores TOTALLY EMPTY inventory galore stock mispriced',
#  'gets NASDAQ Delisting Notice How worrisome Maybe board quit diluting shares',
#  'running away spoon looking healthy pull back longterm target IRA play',
#  'RT needs hold Broken Needs big flush Still technically oversold big bounce yet',
#  'Micron Shares Pounded On Fears Of Loss Of Business From Apple Stifel Defends',
#  'End Of Day Scan Bullish MA Crossovers wwdailystockplayscom',
#  'MettlerToledo ready breakout',
#  'Never told situation Buy dip',
#  'These companies shld worried iCloud',
#  'MT Amazing seeing everyone suddenly touting Long favorite covered call double dip dividend play',
#  'Tomorrow party time Bears 55',
#  'Nomura ests Xbox platform lose least 2014 may profitable another year',
#  'SQL Server revenue grew doubledigit SQL Server Premium revenue growing 30',
#  'short cover high 30s goes planned LOL',
#  'RECAP rumor morning spinning XBOX unit stock grinds day close highs',
#  'IMO dont think get chance buy UNLESS europe falls otherwise folks wake see earnings good',
#  'still interesting finance play one since 14s hold',
#  'BlackBerry Faucette Simona JMHO playing ignorant smack looks legitimate',
#  'CEO sells 450k april 15thmeh',
#  'Impressive 45 revenue growth yy last quarter Whew',
#  'looking good Calls active month weekly',
#  'Ahha Someone wants',
#  'selling CC',
#  'Morgan weight stock oversold strong buy within month',
#  'get next run',
#  'buy safety equipment maker billion',
#  'fast 56pc dive',
#  'Active puts CBOE 92713 480 Oct 43 Jan 37 Jan15 10',
#  'pre mkt Looks like GAP filledlookin short opt',
#  'RT In mostly red tape morning biggest St50 gainers',
#  'rolling new intraday low Bottom Pickers continue get destroyed',
#  'one looks setting break new lows imho think touts told ya buying 750ish almost sure thing',
#  'Multi Top chart finally leads fall price Stability questioned stock coming weeks tell',
#  'Why looks set fall',
#  'Never told situation Buy dip',
#  'Hedge Fund GSO Scores Win With MBIA Bet Risky bet paid realized banks would have2 compromise',
#  'TradeIdeas Matthews International Corporation MATW Is Todays Strong And Under The Radar Stock',
#  'big trader added 100 April put contracts days ago',
#  'hanging well today still basing pattern eyes',
#  'continues consolidate base',
#  '17 10 IBD50 list Both look good',
#  '580 coming quick FED supports markets 610',
#  'Puts 550 28Jun Profitable trade',
#  '5514 entry idea coming narrow intraday range yesterdays high still',
#  'Casinos red bell 075 047 047 unusual comibinations whats running whats red bell',
#  'Continues consolidate previous break area',
#  'Southwest Is Its Lowest Multiple Ever',
#  'Looks like booking one way ticket 40 week MA near 50 Losing 10 week',
#  'Whats Numbers looked good great good think conference call instill confidence',
#  'Bounced support early week indicators turning RSI MACD SMI Worth look',
#  'Outlook Q1 2013 lost revenue range million million good',
#  'Signs life emerging',
#  'Selling far weeks ago noted large bearish channel formed measured move',
#  'Accumulation chart continues make new highs showing accumulation continuing take place',
#  'hot',
#  'End Of Day Scan Stochastic Overbought wwdailystockplayscom',
#  'End Of Day Scan Stochastic Overbought wwdailystockplayscom',
#  'Inside week buy triggers',
#  'Increases Annual Dividend Target',
#  'MY short worked Thank hint puts 50',
#  '100 upside left next mnths based nov 2010 100 based july 2007 History rhymes',
#  'LinkedIn Revenue Up Nearly 50',
#  'Curious know Is 220 Is 74 LNKD great doesnt potential side Fb And Seems little high also',
#  'Daily Phase retest Price experiencing early rejection Can retest',
#  'Still short areanext stop could Someone slammed hard 23000 shs More follow',
#  'RT looks primed also poised run',
#  'Entering long Lockheed Martin Thursdays open',
#  'biggies must loading lows',
#  'Never told situation Buy dip',
#  'LEE ready exit bankruptcy Strong volume today',
#  'March LED light bulb prices rise Japan fall markets',
#  'later riser like last days Jan 14 Healthcare Conference presentation Positive catalyst',
#  'Active puts CBOE 92713 480 Oct 43 Jan 37 Jan15 10',
#  'cant understand logic shorting Oh well helps price go guess',
#  'While fear mechanically driving public markets LOWER record corp cash cheap financing fueling wave acquisitions',
#  '2776 011 gain',
#  'Regional Banks Are Especially Primed Liftoff Even Entire Sector Will Benefit',
#  'Any1 somehow spinning ER stellar something negative some1 got caught short Should rise 2morrow',
#  'My 50 80 Calls going Blessing Daughters tuition',
#  'trouble earnings gap still unfilled 82',
#  'Coal stocks poking head Heres looking earlier week nice weekly candle',
#  'Took small position hopefully better outcome getting kneecapped selling dirt cheap 3650',
#  'love stocks freefall struggle climb',
#  'BULLISH Engulfing COCA COLA',
#  'missed earnings expectations last two quarters today’s strong results came major surprise',
#  'Never told situation Buy dip',
#  'She wants take wants bad apparently People still coming This EOD could explosive shorts get caught',
#  'Investors broke news Company confirmed positive top notch Investor DD trusted',
#  'Lets see higher highs higher lows rest day slow steady',
#  'Break HOD volume nice consolidation completed another run',
#  'Rob added PT Subsidies 300 sales PT consensus',
#  'Downbeaten stocks may ripe buys',
#  'short',
#  'Inside week buy triggers',
#  'Looking oversold bounce',
#  'My god Market getting crushed today Gotta hold anything recover tomorrow imagine',
#  'Oversold falling wedge positive divergence place launch pad looking bounce',
#  'Okay im looking add gold miner possibly lower pe tech name close tmrw Watching',
#  'anyone see last minute BIG BUY yesterday close',
#  'breaking market pulls back',
#  'New bullish conversation activity Had quiet past 48 hours',
#  'bot 224',
#  'moves TR1 long watchlist',
#  'Surprising see sales numbers still holding well guess high end might concern',
#  'pushed jack monkeys This thing short soon Gonna add sedond short somewhere high 14s get',
#  'Long setup One name many coal sector displaying pattern',
#  'IMO dont think get chance buy UNLESS europe falls otherwise folks wake see earnings good',
#  'time sell banks',
#  'meanwhile absolute garbage still stores TOTALLY EMPTY inventory galore stock mispriced',
#  'Getting attention No2 NYSE 100 top buying list',
#  'GO GO get Bermuda Triangle plenty daylight',
#  'strong move today Junior Gold Miners keep EYE gap fill',
#  'Intraday BO bull flag',
#  'Does want go risk appetite still high',
#  'LOOKS like bouncing Would nice finish today make hammer Nice volume 577 bottom Fingers crossed',
#  'End Of Day Scan Stochastic Overbought wwdailystockplayscom',
#  'End Of Day Scan Stochastic Overbought wwdailystockplayscom',
#  'yes Bernanke said hed buy floor It cant go bankrupt anymore',
#  'Worst stock 2015',
#  'Out Jan calls 05 Too illiquid liking',
#  'RT Wanna see awesomely bullish stocks Check Europe might mess people still shipping stuff',
#  'think plenty room run lots momentum continue pushing new highs Currently PT',
#  'RT FITZSTOCK2004 Transports always lead way broke DT line 1st MACD cross bull flag',
#  'RT VMarkets Are Still Acting Weak',
#  'trying lead higher gonna tough',
#  'buy programs popping close print cheap money means higher stock prices robot buying',
#  'Short week next week Charts targeting high Still holding 150 shares 450 SL 7911',
#  '30Minute Chart Small caps threatening descending triangle breakdown',
#  'relative weakness pretty apparent short boat getting full one prefer boat closer empty',
#  'pull back 294 similar last 4286282273 262bullish LOD holds',
#  'conditions sent markets tumble hitting week',
#  'Time stomp dreams',
#  'Equity indexes working positive engulfing March Smallcaps semis fakeout bout',
#  '11 industrialgoods stocks insiders bullish',
#  'Top Japan ETFs To Surge Higher In 2H',
#  'trading alltime high strong earnings report days short interest',
#  'holding well today',
#  'ISRG Short',
#  'Up high volume biotech',
#  'Dont short stock might get left behind',
#  'bullish pennantsymmetrical triangle bo progress Long BOOM',
#  'This rough climb top Many traders bag holders looking get',
#  'somebody bought sep 30 calls 1134 half hour later gets acquired think little fishy',
#  'Is It Finally Right Time Invest National Bank Greece via',
#  'Double bottom handle buy point 2951',
#  'Long Position UP',
#  'SEE YA ABOVE',
#  'Every Reason Be Bullish Into The Stock Drop u279a',
#  'RT Long 395great find hope wold another still holding second 12',
#  'back small post',
#  'test 10 next days time take profits hedge puts',
#  'Called back march still loving today',
#  'stocks large players selling',
#  'Money flow positive',
#  'NOOBS bios small caps stock splits lipstick pig Splits mid mega caps Not pos',
#  'Up away',
#  'stocks came screens longs',
#  'Never told situation Buy dip',
#  'important pragmatic analysishigh prices could offer headwindsbullish story intactevenif market rolls',
#  'Never told situation Buy dip',
#  'technical alerts Stochastic Sell Signal 200 DMA Support 50 DMA Support',
#  'Ten year yield weekly 10 year yield still bearish hence 710 year bond fund bullish',
#  'CEO says 1824 months settling patent issues Gileadmy take stock selling Ppl expecting sooner resolution',
#  'share total value company crunching The 4g technology diamond rough',
#  'Google Inc completes acquisition ICOA Inc',
#  'staying strong',
#  'explains going put Watson work destroy ton jobs make ton money',
#  'THE play today aint bad iether',
#  'Okay im looking add gold miner possibly lower pe tech name close tmrw Watching',
#  'funny thing 19 AH approval',
#  '10 premarket ready lift',
#  'Momentum bird flu continue started Meanwhile Ibio seems gaining big money Shorts hurting',
#  'RT Down day biotechs Good load Be confident Agreed downness',
#  'Looks good weekly chart',
#  'put money better option drug already make money indication potential next qe',
#  'havent seen vol like since runup lets see one dip 20x',
#  'Potential continuation Uptrend 60154 charts',
#  'Receives 7Year Contract New Saudi Arabian Steel Mill',
#  'ready pop',
#  'soars premarket business split announcement rumors looking shed stake buyer LOL',
#  'Okay im looking add gold miner possibly lower pe tech name close tmrw Watching',
#  'Says Breakup Will Cost Billions Sees Savings Too',
#  'short sighted sellers sorry soon',
#  'soars premarket business split announcement rumors looking shed stake buyer LOL',
#  'In oversold conditions showing nice positive divergences chart Potential Bounce Player watch',
#  '11 industrialgoods stocks insiders bullish',
#  'Looking stock make new 2013 high tomorrow',
#  'shorts made killing last couple days might make cover buy back',
#  'Why sell credit spread may one money Call credit spread',
#  'Okay im looking add gold miner possibly lower pe tech name close tmrw Watching',
#  'Jan sinking ship',
#  'Resuming advance new historical highs',
#  'WHy exploding Like seriouslylol',
#  'Stay With Best Of Breed Has Room To Run via options',
#  'RT Down day biotechs Good load Be confident Agreed downness',
#  'Slow bleeding death The 421 eps report determine stocks fate It likely horror show event Replace',
#  'well considering dilution works make sure set high sell limit order whatever think worth',
#  'End Of Day Scan Stochastic Overbought wwdailystockplayscom',
#  'End Of Day Scan Stochastic Overbought wwdailystockplayscom',
#  'Come party buy gonna give solid gains dividend',
#  'Found good bull setups week Lets see mkt helps',
#  'getting oil falling opec insane want us shale collapse',
#  'If bulls lucky enuff get upside gap fill better take Wouldnt chase',
#  'Halliburton HAL Stock Trading Lower Today 2015 Warning After Upbeat Earnings Results',
#  'Potential continuation Uptrend 60154 charts',
#  'Rival companies WATCO eyeing takeover interest',
#  'LONG 744',
#  'It may risky rush Ill give Just make sure dont go long money Play safe long',
#  'Will reenter short bounce',
#  'resurgence stock price today might mean company may emerge stronger ever',
#  'whos buying',
#  'With Oil Prices Down Oil Stocks Looking Less Cheap',
#  'like optimism moving NCE Agenda may simple claim active moiety',
#  'back tight',
#  'youre trading name Key levels wk nice consolidation wlow volume',
#  'Current holdings via options Long Short',
#  'looking weak market moving higher good sign Unless get 157 early short 15400 today',
#  'Watch bancostheyre holding relatively well compared broad market large buying backburner',
#  'sells flatI',
#  'BlackBerry Faucette Simona JMHO playing ignorant smack looks legitimate',
#  'PNC Goldman Sachs Receive Dividend Hike Green Light But Dont Act',
#  'might selling ahead earnings',
#  'selling sync SPand rest 90 stocks directional trade',
#  'much better day',
#  'short didnt work small bet puts',
#  'Gap September Comparable Store Sales',
#  '25 since Tue morning',
#  'Long brealout trade',
#  'Weird day',
#  'would guessed would kill would sucknot lol',
#  'Hit With Lawsuit Russian Search Engine',
#  'Nasdaq Sets Up Breakout Part II via',
#  'agree end world buy',
#  'breakout likely medium target',
#  'These companies shld worried iCloud',
#  'running',
#  'Google Inc completes acquisition ICOA Inc',
#  'resistance turned support It',
#  'Published estimate Estimize 003 EPS 2998M Revs compared Wall Streets consensus',
#  'April 780 calls bro',
#  'Tomorrow party time Bears 55',
#  'Google Will Soon Start Selling Chromebooks At Walmart And Staples Other Retailers Coming Soon',
#  'Testing 200 day consolidation',
#  'would guessed would kill would sucknot lol',
#  'Long Position',
#  'stocks large players selling',
#  'Hold Buy 4Sure NOT Sell way low Ive lost position wondering others holding buying selling',
#  'finding support 10day line far',
#  'Three hot stocks today Thanks',
#  'The directors know stock cheap If insider Id buying Oh wait buying',
#  'Reuters Green Mountain revenue misses shares plunge prints 4380 market foul mood bad day disappoint',
#  'RT waterfall ahead',
#  'Here come shorts marchin Lovin',
#  'MY short worked Thank hint puts 50',
#  'way acting may fall 65 today horrible action since hit 70 yesterday',
#  'good news domestic automakers',
#  'Crude Oil Bears Take Clear Near Term Advantage',
#  'Daily chart though RSI Stoch point possible move theres lot resistance',
#  'Europe banks implode The stress tests failing Big Swirl near bonds CDS debt cash gold selloff',
#  'On closer inspection Resistance 10 points north 200d downward trendline Chart',
#  'If shorted GoldSilver recently bottom enjoy bull run started',
#  'Scans later couple notes Very rarely Intermarket RS list 20pt mover week went 26 66',
#  'Note monthly chart recaptured support possible double bottom set',
#  'US Adds 321K Jobs In November Most Since 2012 Unemployment Rate Remains At 58 Gold Futures',
#  'Sandbagged guidance use last billion CC cautiously optimistic wait til Next ER confirmation',
#  'go 99 add 100',
#  'still smaller pos Being tender cash due volatility So reluctant keep many big positions',
#  'PLUNGING Back',
#  'noticed didnt get back 15 todaythat cant good',
#  'Looks like support line around 2490 held If close green could start seeing pstv momentum esp 20day',
#  'US Adds 321K Jobs In November Most Since 2012 Unemployment Rate Remains At 58 Gold Futures',
#  'strong move today Junior Gold Miners keep EYE gap fill',
#  'Intraday BO bull flag',
#  'Crude Oil Bears Take Clear Near Term Advantage',
#  'turns ST Weak Bearish Stock Trends Report Mrk Vectr Gold Miners ETFÂ',
#  'Note monthly chart recaptured support possible double bottom set',
#  'bull bear way cut',
#  'watching China ppi cpi reporting tonight Commods super sensitive china still Could offer support revisit jump long bus',
#  'strong move today Junior Gold Miners keep EYE gap fill',
#  'Intraday BO bull flag',
#  'Buying Weakness 06302015',
#  'Buffetts 13F Shows New Stakes CVS Visa General Dynamics',
#  'see longs talking trash buying magically bought dollar Impressive trading',
#  'Breakout Coming Soon',
#  'new large player sells stocks',
#  'Add positions posted earlier Exit',
#  'Has European debt crisis entered dangerous new phase',
#  'Euro probing support 12650 still',
#  'EURUSD Finding Support Near 110 Level',
#  'people shortsighted opened red significantly day continue surge next week',
#  'need anoth time high new high',
#  'Breakout today reporting earnings last night',
#  'RT best movers today dont give Ill sorry Huge contract starting Nov Indiamoving today',
#  'Haha stock price well cash value Bears piling face rip',
#  'could teens one trading day 60 short interest',
#  'Maglan Capital Up 2084 In February Long Fairpoint',
#  'Morgan Stanley tricky bastards Ran price ER gave upgrade shorted',
#  'Wouldnt surprised oil Cheaper oil introduce shipment higher tanker rates',
#  'End Of Day Scan Stochastic Overbought wwdailystockplayscom',
#  'End Of Day Scan Stochastic Overbought wwdailystockplayscom',
#  'Ha Heere comes pump So glad picked 9K end day Get ready bull ride',
#  'sold today 313 526 40 loss Well shouldve attentive one badmoving',
#  'Going read quarterlies listen calls bead one looking beat interesting already',
#  'Think challendge 200EMA distant future Look yesterdays volume',
#  'LOL back darn shorts No chit Sherlock',
#  'Reports Q3 EPS vs Est Revenues vs Est',
#  'Slowly adding gotta careful This one biggest winners 2012',
#  'wont stay',
#  'quick 2135 market tanking scaling longs',
#  '2012 big',
#  'Erinn Murphy Piper Jaffray thinks BUY',
#  'End Of Day Scan Bullish MA Crossovers wwdailystockplayscom',
#  'gold going parabolic wonder keep chasing tops boys',
#  'RT Wanna see awesomely bullish stocks Check Europe might mess people still shipping stuff',
#  'buy whatever Carl Icahn buys wait Seems like easy way make big money Im looking Icahns holdings',
#  '32 gap fill coming',
#  'watching China ppi cpi reporting tonight Commods super sensitive china still Could offer support revisit jump long bus',
#  'As 3x ETFs subject decay due daily rebalancing careful holding For long term hold safer',
#  'Its like Christmas May',
#  'Problem shorts Facebook every fund want buy thing pullback Not good anymore',
#  'It looks like thumb far No like At least didnt go 38 yet It supported IPO maker',
#  'Nice buyable intraday dip right',
#  'Key level watch today 2553 watching see hold support',
#  'Dax says bye bye 2013 finished great yr 28 plus',
#  'Could pride social media gettin ready fall chart rolling',
#  'Is BUY Topeka Capital Markets thinks',
#  'Big Money Is Pouring Into Facebook From All Directions',
#  'longs right throw towel run back hods lol',
#  'churning high volume IPO price Lots sellers trying get Might take consolidate moving higher',
#  'SHIFTING ON THE 15 MINUTE HERE SUSPECT TO TAKE HIGHS',
#  'If positive monetizing aspect todays event watch drop',
#  'beautifully orchestrated market would like know mm fb',
#  'may take days wks months watch happened IPO mrkt needs washout hunt well need wait stalk',
#  'Free Net Africa First ROI piss investors big picture BRILLIANT Boywonder visionary Zuck',
#  'Curious know Is 220 Is 74 LNKD great doesnt potential side Fb And Seems little high also',
#  'Facebook Bull Candle 552',
#  'guess want look sell orders',
#  'strong 5min bollies',
#  'Undaunted By String Of Failures Facebook Is Trying To Get Into Payments',
#  'So todays close 81514 Im long longerterm technical swing long basis',
#  'cant remember FB last bad quarter dont see lower',
#  'hitting everything sightshort twtr',
#  'stock outperform heres',
#  'bot breakout consolidation zone',
#  'close 49monday freewater fall like white water rafting',
#  'Short dont know means markets tank',
#  'chartist news MM talk orchestrated BS Long tech early Jan straight calls',
#  '11 industrialgoods stocks insiders bullish',
#  'Buying last week play month Wish woulda pulled trigger',
#  'Putting little short prevailing wisdom notwithstanding',
#  'Ford well All businesses trying buy EOY',
#  'The sun rises East sets West Water wet Fire hot And Ford stock goes Its Accept',
#  'expects earnings maintain healthy growth year ahead The company’s share price gained 016',
#  'good news domestic automakers',
#  'bot 6870 bot 2550',
#  'RT 3185 looks good',
#  'Exact EXAS Flagged As Strong On High Volume',
#  'yeah Even looking pretty attractive versus pig Or SOX trading 36x reported earning',
#  'Has European debt crisis entered dangerous new phase',
#  'Still cogniscicent Euro mess ensuing newsflow',
#  'StockMasters European Debt Keeps Stocks Down',
#  'Has European debt crisis entered dangerous new phase',
#  'making new highs year Doesnt normally produce great stocks trade may bad swing',
#  '11 industrialgoods stocks insiders bullish',
#  'UPGRADE today MS overweight Excellent company leadership',
#  'Accumulating GOBS outshined',
#  'lows BK real possibility',
#  'Nice little cupandhandle shaping 15minute Endofday favours good day index Will see gap open',
#  'market lot faith ECB',
#  'EURUSD Finding Support Near 110 Level',
#  'Has European debt crisis entered dangerous new phase',
#  'Philippines rapid expanding economy FDI higher previous years 264 days',
#  'HeadShoulders bullish reversal setup breakout Oil Gas Pipleline stock',
#  '11 industrialgoods stocks insiders bullish',
#  'These companies shld worried iCloud',
#  'bear flag',
#  'soars premarket business split announcement rumors looking shed stake buyer LOL',
#  'Now blame clubs terrible golfer downgraded Neutral Wedbush PT Lowered 700',
#  'longscongratsanother HOD',
#  'Quality Stocks With High Cash Returns',
#  'RT looks primed also poised run',
#  'stocks came screens longs',
#  'hod posted buy pm',
#  'bouncing nicely addon posted',
#  'shoots MOON favorite pumper would say know We still luv man make us laugh Heres hoping ur right',
#  'Found good bull setups week Lets see mkt helps',
#  'still wanted get morning missed',
#  'nice breakout recent consolidation Congrats',
#  'two dollar spec play long term investment Ive held since 34 Ur penny scalps cost wIRS Good luck lol',
#  'pure garbage stock',
#  'EA Launches Origin Online Game Distribution Mac via MacRumors',
#  'points two Facebook games accuses copyright infringement',
#  'Making higher highs higher lows consolidates past several weeks 2670 time high 2006',
#  'RT correleation dollar index simply amazing finds support retreats like clockwork',
#  'My play today Im still skeptical Will take profits Not time cheer',
#  'End Of Day Scan Stochastic Overbought wwdailystockplayscom',
#  'End Of Day Scan Stochastic Overbought wwdailystockplayscom',
#  'Patience pays holding theseif bought lowest nothing worry abouteven catching falling knife',
#  'Buying Weakness 06302015',
#  'weekly stochastics finally starting turn long consolidation Buying',
#  'Beautiful trendbase technicals pointing Solid accumulation Looks good Weekly next',
#  'Quality Stocks With High Cash Returns',
#  'like thisoil biz new drillerships',
#  'BTW turmoil MENA region shippers perform oil performs turmoil',
#  'broke bull flag channel make new highs volume poor',
#  'Inside week buy triggers',
#  'ripe continuation',
#  'picked like going 2014',
#  'Following mornings EPS blew added longs',
#  'Inside week buy triggers',
#  'Love donuts coffee Hate plunges 40 One time goes long term chart Perfect buy',
#  'RT Down day biotechs Good load Be confident Agreed downness',
#  'Never told situation Buy dip',
#  'green moving',
#  'stocks came screens longs',
#  'going',
#  'yes hopefully italy falls apart importanlty hope falls apart',
#  'iGrid shows capped long term range 12340 12477any rally beyond todays levels range leads meltdown',
#  'years alot worry',
#  'Time stomp dreams',
#  'technical alerts Gilligans Island Buy Setup Stochastic Buy Signal Lizard Bullish Hammer Candlestick Wid',
#  'would rather buyer UGAZ levels trying sell DGAZ top',
#  'gonna start shorting every 10 move',
#  'double bottom bounce drops Gap fill 5474 wait see taking action',
#  'Top Japan ETFs To Surge Higher In 2H',
#  'looking cheap fundimentally hereill TA game',
#  '4844 targeting 51',
#  'wow tank',
#  'If stock hits loss sell exceptions crying get',
#  'Hope Crush',
#  'Sinks 35',
#  'The Total Flop Of 3D Printing',
#  '3D Systems DD Stock Receives Ratings Downgrade Today Jefferies',
#  'Near HOD',
#  'NaturalGas Settles At 3year Low',
#  'breaking',
#  '080 right also looks like nice riskreward starting initiate position Waiting FDA feedback KRN5500',
#  'Chinese ADRs heading higher watchlist',
#  'congress probably long fcking right',
#  'looks like ascending channel Finfiz',
#  'Anyone know whats big sell',
#  'guess sold 107 reaction 45 minutes',
#  'Buffetts 13F Shows New Stakes CVS Visa General Dynamics',
#  'China winners',
#  'todays top gainers stocks',
#  'one watch much would watch 821 emas acted support position',
#  'getting killed calls well see happens next',
#  'Okay im looking add gold miner possibly lower pe tech name close tmrw Watching',
#  'lots nice setups Energy liking Whiting day',
#  'With Oil Prices Down Oil Stocks Looking Less Cheap',
#  'Upgraded buy Alpha Street Research',
#  'Component supplier falls sale',
#  'stocks large players selling',
#  'Accumulating GOBS outshined',
#  'Sep 40 calls 35 since entry BANG',
#  'Potential intermediate top Uptrend 60154 charts',
#  'time accumulate long position far upside downside',
#  'looks like big feb 1822 spread Last quarter YoY rev growth trading 24x earnings may try short',
#  'March LED light bulb prices rise Japan fall markets',
#  'Downbeaten stocks may ripe buys',
#  'new large player sells stocks',
#  '1Mil Buy order',
#  'Buyback trending right spending shares pricier Hopefully pull back 687 Q2 closing VWAP',
#  ...]

# %%
analyser = SentimentIntensityAnalyzer()

# %%
prediction=[]
for sent in sentences:
    prediction.append(analyser.polarity_scores(sent)['compound'])

# %%
len(intensity)
# Out:
# 3789

# %%
len(prediction)
# Out:
# 3789

# %%
sqrt(mean_squared_error(intensity, prediction))
# Out:
# 0.4341581523275996
